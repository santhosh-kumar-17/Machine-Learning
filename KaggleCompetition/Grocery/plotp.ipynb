# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('transactions.csv')

# %%
df.head()
# Out:
#             store_nbr  transactions
# date
# 2013-01-01         25           770
# 2013-01-02          1          2111
# 2013-01-02          2          2358
# 2013-01-02          3          3487
# 2013-01-02          4          1922

# %%
df.plot(x='store_nbr',y='transactions',figsize=(10,10))
plt.xlabel('date')
plt.ylabel('locale')
plt.title('Holiday_Events')
plt.show()

# %%
df.describe()
# Out:
#           store_nbr  transactions
# count  83488.000000  83488.000000
# mean      26.939237   1694.602158
# std       15.608204    963.286644
# min        1.000000      5.000000
# 25%       13.000000   1046.000000
# 50%       27.000000   1393.000000
# 75%       40.000000   2079.000000
# max       54.000000   8359.000000

# %%
Listt=[]
val=0
for i in range(10):
    va=input(int)
    Listt[i]=val
print(Listt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 for i in range(10):
#       4     va=input(int)
# ----> 5     Listt[i]=val
#       6 print(Listt)
#
# IndexError: list assignment index out of range
